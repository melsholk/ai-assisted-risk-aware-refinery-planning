# %% [markdown]
# # Base case run (Phase 1)
# This notebook runs the deterministic refinery LP and prints the planning run report.

# %%
from src.model import load_data, build_and_solve_lp
data = load_data('data')
report = build_and_solve_lp(data, verbose=True)
report['products']
